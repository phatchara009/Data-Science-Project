# %% [markdown]
# # 1. Lending Club Dataset 🏦

# %% [markdown]
# ## Dataset Sources
#
# `Main Data` : https://www.kaggle.com/datasets/wordsforthewise/lending-club/code
#
# `Dataset (Subset-Main data)` : https://www.kaggle.com/datasets/jeandedieunyandwi/lending-club-dataset
#
# `Dataset Dictionary` : https://www.kaggle.com/datasets/wordsforthewise/lending-club/discussion/384519

# %% [markdown]
# ## Dataset Dictionary
#
# ---
# ----
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LoanStatNew</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>loan_status</td>
#       <td>สถานะปัจจุบันของเงินกู้</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>loan_amnt</td>
#       <td>จำนวนเงินกู้ที่ยื่นขอโดยผู้กู้ (หากฝ่ายสินเชื่อลดจำนวนเงินกู้ลง ก็จะถูกแสดงในค่านี้)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>installment</td>
#       <td>ค่างวดเงินผ่อนที่ชำระในแต่ละงวด</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>term</td>
#       <td>อายุของเงินกู้มีอยู่ 2 ค่าได้แก่ 36 เดือนและ 60 เดือน</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>int_rate</td>
#       <td>อัตราดอกเบี้ยเงินกู้</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>grade</td>
#       <td>เกรดสินเชื่อที่ Lending Club เป็นคนกำหนด</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>sub_grade</td>
#       <td>เกรดสินเชื่อระดับย่อยที่ Lending Club เป็นคนกำหนด</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>verification_status</td>
#       <td>ระบุว่ารายได้ได้รับการยืนยันโดย LC หรือไม่ได้รับการยืนยัน หรือแหล่งที่มาของรายได้ได้รับการยืนยันหรือไม่</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>annual_inc</td>
#       <td>รายได้ประจำปีของผู้กู้</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>dti</td>
#       <td>อัตราส่วนที่คำนวณโดยใช้ยอดชำระหนี้ต่อเดือนของผู้กู้ต่อภาระหนี้ทั้งหมด ไม่รวมค่าจดจำนองและเงินกู้ LC ที่ขอ หารด้วยรายได้ต่อเดือนของผู้กู้ที่รายงานด้วยตนเอง</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>emp_title</td>
#       <td>ตำแหน่งงานที่ผู้กู้ระบุเมื่อสมัครขอสินเชื่อ*</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>emp_length</td>
#       <td>อายุงานเป็นปี ค่าที่เป็นไปได้อยู่ระหว่าง 0 ถึง 10 โดยที่ 0 หมายถึงน้อยกว่าหนึ่งปี และ 10 หมายถึง 10 ปีขึ้นไป</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>home_ownership</td>
#       <td>สถานะความเป็นเจ้าของบ้านที่ผู้กู้ระบุระหว่างการลงทะเบียนหรือได้รับจากรายงานเครดิต ค่านิยมของเราคือ: เช่า(RENT), เป็นเจ้าของ(OWN), จำนอง(MORTGAGE), อื่นๆ(OTHER)</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>issue_d</td>
#       <td>เดือนที่กู้เงิน</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>earliest_cr_line</td>
#       <td>เดือนที่เปิดวงเงินสินเชื่อที่รายงานเร็วที่สุดของผู้กู้</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>title</td>
#       <td>หัวข้อของเงินกู้ที่ผู้กู้เป็นคนกำหนด</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>purpose</td>
#       <td>หมวดหมู่ที่ผู้กู้จัดเตรียมไว้สำหรับการขอสินเชื่อ</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>total_acc</td>
#       <td>จำนวนบัญชีวงเงินสินเชื่อทั้งหมดในปัจจุบันที่แสดงอยู่ใน Credit file ของผู้กู้</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>open_acc</td>
#       <td>จำนวนบัญชีวงเงินสินเชื่อแบบเปิดที่แสดงอยู่ใน Credit file ของผู้กู้ (จะน้อยกว่า total_acc เสมอ)</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>revol_bal</td>
#       <td>ยอดคงเหลือหมุนเวียนของเครดิตทั้งหมด</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>revol_util</td>
#       <td>อัตราการใช้วงเงินหมุนเวียนหรือจำนวนเครดิตที่ผู้กู้ใช้เทียบกับสินเชื่อหมุนเวียนที่มีอยู่ทั้งหมด</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>initial_list_status</td>
#       <td>สถานะรายการเริ่มต้นของสินเชื่อ ได้แก่ W และ F</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>application_type</td>
#       <td>รูปแบบการชำระเงินของสินเชื่อ ได้แก่ ขอสินเชื่อบุคคล (Individual), ชำระผู้กู้ร่วม 2 คน (Joint) และระบบการชำระเงินออนไลน์โดยหักเงินจากบัญชีอัตโนมัติ (Direct pay)</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>mort_acc</td>
#       <td>จำนวนบัญชีที่ใช้อสังหาริมทรัพย์ในการจำนองเพื่อขอกู้สินเชื่อ</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>pub_rec</td>
#       <td>จำนวนบันทึกสาธารณะที่เสื่อมเสีย</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>pub_rec_bankruptcies</td>
#       <td>จำนวนครั้งของการล้มละลาย</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>address</td>
#       <td>รัฐจัดทำโดยผู้กู้ในการขอสินเชื่อ</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>zip_code</td>
#       <td>รหัสไปรษณีย์ผู้กู้ระบุในใบสมัครสินเชื่อ ได้มาจาก address</td>
#     </tr>
#   </tbody>
# </table>
#
# ---
# ----

# %% [markdown]
# ## `Import Library`

# %%
# !pip install imblearn
# !pip install lightgbm
# !pip install xgboost

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn import *

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from imblearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV


from sklearn.metrics import (
    accuracy_score, confusion_matrix, classification_report,
    roc_auc_score, roc_curve, auc
)

from sklearn.metrics import ConfusionMatrixDisplay, RocCurveDisplay

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

import lightgbm as lgb
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier

pd.set_option('display.float', '{:.2f}'.format)
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %% [markdown]
# ## `Import the dataset`

# %%
data = pd.read_csv("lending_club_loan_two.csv")
data.sample(5)
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 167450    5000.00   36 months      6.49       153.23     A        A2
# 339439   19200.00   60 months     13.35       440.31     C        C2
# 37707    12175.00   36 months     10.16       393.77     B        B1
# 101279   30000.00   36 months     18.55      1092.87     D        D2
# 39949    18000.00   36 months     13.11       607.45     B        B4
#
#               emp_title emp_length home_ownership  annual_inc  \
# 167450  Account Manager  10+ years           RENT    70000.00
# 339439           Repair  10+ years       MORTGAGE   100000.00
# 37707    Bozzuto's Inc.    8 years           RENT    35000.00
# 101279              NaN    7 years       MORTGAGE   225000.00
# 39949     VW Credit Inc  10+ years       MORTGAGE    65000.00
#
#        verification_status   issue_d loan_status             purpose  \
# 167450     Source Verified  Nov-2014  Fully Paid  debt_consolidation
# ...

# %%
data.describe()
# Out:
#        loan_amnt  int_rate  installment  annual_inc       dti  open_acc  \
# count  396030.00 396030.00    396030.00   396030.00 396030.00 396030.00
# mean    14113.89     13.64       431.85    74203.18     17.38     11.31
# std      8357.44      4.47       250.73    61637.62     18.02      5.14
# min       500.00      5.32        16.08        0.00      0.00      0.00
# 25%      8000.00     10.49       250.33    45000.00     11.28      8.00
# 50%     12000.00     13.33       375.43    64000.00     16.91     10.00
# 75%     20000.00     16.49       567.30    90000.00     22.98     14.00
# max     40000.00     30.99      1533.81  8706582.00   9999.00     90.00
#
#         pub_rec  revol_bal  revol_util  total_acc  mort_acc  \
# count 396030.00  396030.00   395754.00  396030.00 358235.00
# mean       0.18   15844.54       53.79      25.41      1.81
# std        0.53   20591.84       24.45      11.89      2.15
# min        0.00       0.00        0.00       2.00      0.00
# ...

# %% [markdown]
# # 2. Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %% [markdown]
# ## `Correlation of Numeric variables`

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## `loan_status`
# > สถานะของเงินกู้
# > - Fully Paid คือ จ่ายครบแล้ว
# > - Charge Off คือ ผิดนัดชำระหนี้

# %%
print(data["loan_status"].value_counts())

print(data["loan_status"].value_counts(normalize = True))
# Out:
# Fully Paid     318357
# Charged Off     77673
# Name: loan_status, dtype: int64
# Fully Paid    0.80
# Charged Off   0.20
# Name: loan_status, dtype: float64

# %%
plt.figure(figsize=(9, 6))

# Create the bar chart using seaborn
sns.countplot(x="loan_status", data=data)

# Set the chart title and axis labels
plt.title("Bar Chart: Count of Observations by loan status")
plt.xlabel("Count of Loan status")
plt.ylabel("Count")

# Display the plot
plt.show()

# %% [markdown]
# ## `loan_amnt`
# > จำนวนเงินกู้ที่ยื่นขอโดยผู้กู้ (หากฝ่ายสินเชื่อลดจำนวนเงินกู้ลง ก็จะถูกแสดงในค่านี้)

# %%
# Print a header
print("\nLoan amont by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "loan_amnt" column
data.groupby(by="loan_status")["loan_amnt"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Loan amont by Loan Status
#                 count     mean     std     min     10%     25%      50%  \
# loan_status
# Charged Off  77673.00 15126.30 8505.09 1000.00 5000.00 8525.00 14000.00
# Fully Paid  318357.00 13866.88 8302.32  500.00 4800.00 7500.00 12000.00
#
#                  75%      90%      95%      max
# loan_status
# Charged Off 20000.00 28000.00 33000.00 40000.00
# Fully Paid  19225.00 25000.00 30000.00 40000.00

# %%
# Set the style of the plot
sns.set_style("whitegrid")

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the box plot using seaborn "Installment"
sns.boxplot(data=data, x="installment", y="loan_status", ax=axes[0])

# Set the chart title and axis labels
axes[0].set_xlabel("Installment")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Installment by Loan status")

# Create the histogram using seaborn "Installment"
sns.histplot(data=data, x="installment", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels
axes[1].set_xlabel("Installment")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: installment by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `installment`
# > ค่างวดเงินผ่อนที่ชำระในแต่ละงวด

# %%
# Print a header
print("\nInstallment by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["installment"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Installment by Loan Status
#                 count   mean    std   min    10%    25%    50%    75%    90%  \
# loan_status
# Charged Off  77673.00 452.70 249.10 21.62 172.09 274.86 399.06 585.67 806.61
# Fully Paid  318357.00 426.76 250.86 16.08 155.93 244.46 369.51 562.89 780.52
#
#                95%     max
# loan_status
# Charged Off 944.78 1527.00
# Fully Paid  918.55 1533.81

# %%
# Set the style of the plot
sns.set_style("whitegrid")

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the box plot using seaborn "Loan Amount"
sns.boxplot(data=data, x="loan_amnt", y="loan_status", ax=axes[0])

# Set the chart title and axis labels
axes[0].set_xlabel("Loan amount")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Loan amount by Loan status")

# Create the histogram using seaborn "Loan Amount"
sns.histplot(data=data, x="loan_amnt", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels
axes[1].set_xlabel("Loan amount")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Loan amount by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `term`
# > อายุของเงินกู้มีอยู่ 2 ค่าได้แก่
# > - 36 months (3 years)
# > - 60 months (5 years)

# %%
data.groupby("term")["loan_status"].value_counts(normalize=True)
# Out:
# term        loan_status
#  36 months  Fully Paid    0.84
#             Charged Off   0.16
#  60 months  Fully Paid    0.68
#             Charged Off   0.32
# Name: loan_status, dtype: float64

# %%
plt.figure(figsize=(9, 6))

# Create a countplot using seaborn
sns.countplot(x="term", data=data, hue="loan_status")

# Set the chart title and axis labels
plt.xlabel("Term")
plt.ylabel("Frequency")
plt.title("Bar Chart: Term by Loan status")

# Display the plot
plt.show()

# %% [markdown]
# ## `int_rate`
# > อัตราดอกเบี้ยเงินกู้

# %%
# Print a header
print("\nInterest rate by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["int_rate"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Interest rate by Loan Status
#                 count  mean  std  min   10%   25%   50%   75%   90%   95%  \
# loan_status
# Charged Off  77673.00 15.88 4.39 5.32 10.25 12.99 15.61 18.64 21.99 23.99
# Fully Paid  318357.00 13.09 4.32 5.32  7.62  9.91 12.99 15.61 18.85 20.99
#
#               max
# loan_status
# Charged Off 30.99
# Fully Paid  30.99

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the box plot using seaborn for "Interest rate" by "Loan Status"
sns.boxplot(data=data, x="int_rate", y="loan_status", ax=axes[0])

# Set the chart title and axis labels
axes[0].set_xlabel("Interest rate")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Interest rate by Loan status")

# Create the histogram using seaborn for "Interest rate"
sns.histplot(data=data, x="int_rate", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the first subplot
axes[1].set_xlabel("Interest rate")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Interest rate by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Set the figure size
plt.figure(figsize=(9, 6))

# Create the box plot using seaborn for "Interest rate" by "Grade"
sns.boxplot(data=data.sort_values(by="grade"), x="grade", y="int_rate")

# Set the chart title and axis labels
plt.xlabel("Grade")
plt.ylabel("Interest rate")
plt.title("Box plot: Interest rate by Grade")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `grade` & `sub_grade`
# > - `grade` : เกรดสินเชื่อที่ Lending Club เป็นคนกำหนด เช่น A, B, C, D, E, F, G (ยิ่ง Grade สูงขึ้นโอกาสการผิดนัดชำระหนี้จะเพิ่มขึ้น)
# > - `sub_grade` : เกรดสินเชื่อระดับย่อยที่ Lending Club เป็นคนกำหนด เช่น A1, A2, A3, ..., G4, G5 (G5 เป็นเกรดระดับต่ำที่สุดและโอกาสการผิดนัดชำระหนี้สูงที่สุด)

# %%
data.groupby("grade")["loan_status"].value_counts(normalize=True)
# Out:
# grade  loan_status
# A      Fully Paid    0.94
#        Charged Off   0.06
# B      Fully Paid    0.87
#        Charged Off   0.13
# C      Fully Paid    0.79
#        Charged Off   0.21
# D      Fully Paid    0.71
#        Charged Off   0.29
# E      Fully Paid    0.63
#        Charged Off   0.37
# F      Fully Paid    0.57
#        Charged Off   0.43
# G      Fully Paid    0.52
#        Charged Off   0.48
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the bar chart using seaborn
sns.countplot(data=data.sort_values("grade"), x="grade", hue="loan_status")

# Set the chart title and axis labels
plt.xlabel("Grade")
plt.ylabel("Frequency")
plt.title("Bar plot: Grade by Loan status")


# Display the plot
plt.show()

# %%
data.groupby("sub_grade")["loan_status"].value_counts(normalize=True)
# Out:
# sub_grade  loan_status
# A1         Fully Paid    0.97
#            Charged Off   0.03
# A2         Fully Paid    0.95
#            Charged Off   0.05
# A3         Fully Paid    0.94
#                          ...
# G3         Fully Paid    0.49
# G4         Fully Paid    0.55
#            Charged Off   0.45
# G5         Charged Off   0.50
#            Fully Paid    0.50
# Name: loan_status, Length: 70, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the bar chart using seaborn
sns.countplot(data=data.sort_values("sub_grade"), x="sub_grade", hue="loan_status")

# Set the chart title and axis labels
plt.xlabel("Sub Grade")
plt.ylabel("Frequency")
plt.title("Bar plot: Sub Grade by loan status")
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Create the histogram using seaborn for "Grade"
sns.countplot(
    data=data[(data.grade == "F") | (data.grade == "G")].sort_values(["sub_grade", "loan_status"]),
    x="grade", hue="loan_status", ax=axes[0]
)

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("Grade")
axes[0].set_ylabel("Frequency")
axes[0].set_title("Histogram: Grade by Loan status")

# Create the histogram using seaborn for "Sub Grade"
sns.countplot(
    data=data[(data.grade == "F") | (data.grade == "G")].sort_values(["sub_grade", "loan_status"]),
    x="sub_grade", hue="loan_status", ax=axes[1]
)

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Sub Grade")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Sub Grade by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `verification_status`
# > ระบุว่ารายได้ได้รับการยืนยันโดย Lending Club หรือไม่ได้รับการยืนยัน หรือแหล่งที่มาของรายได้ได้รับการยืนยันหรือไม่ ได้แก่
# > - Verified ถูกยืนยันแล้ว
# > - Source Verified ถูกยืนยันแล้ว
# > - Not Verified ยังไม่ได้รับการยืนยัน

# %%
data.groupby("verification_status")["loan_status"].value_counts(normalize=True)
# Out:
# verification_status  loan_status
# Not Verified         Fully Paid    0.85
#                      Charged Off   0.15
# Source Verified      Fully Paid    0.79
#                      Charged Off   0.21
# Verified             Fully Paid    0.78
#                      Charged Off   0.22
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create a countplot using seaborn
sns.countplot(x="verification_status", data=data, hue="loan_status")

# Set the chart title and axis labels
plt.xlabel("Verification status")
plt.ylabel("Frequency")
plt.title("Bar Chart: Verification status by Loan status")

# Display the plot
plt.show()

# %% [markdown]
# ## `annual_inc`
# > รายได้ประจำปีของผู้กู้

# %%
# Print a header
print("\nAnnual Income by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["annual_inc"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Annual Income by Loan Status
#                 count     mean      std    min      10%      25%      50%  \
# loan_status
# Charged Off  77673.00 67535.54 58303.46   0.00 31000.00 42000.00 59000.00
# Fully Paid  318357.00 75829.95 62315.99 600.00 35000.00 46050.53 65000.00
#
#                  75%       90%       95%        max
# loan_status
# Charged Off 80000.00 110000.00 137440.00 8706582.00
# Fully Paid  90000.00 125000.00 150000.00 7600000.00

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the box plot using seaborn for "Annual income" by "Loan Status"
sns.boxplot(data=data, x="annual_inc", y="loan_status", ax=axes[0])

# Set the chart title and axis labels
axes[0].set_xlabel("Annual income")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Annual income by Loan status")

# Create the histogram using seaborn for "Annual Income"
sns.histplot(data=data, x="annual_inc", hue="loan_status", bins=1000, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Annual Income")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Annual Income by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the box plot using seaborn for "Annual income" by "Loan Status"
sns.boxplot(data=data[data.annual_inc <= 150000], x="annual_inc", y="loan_status", ax=axes[0])

# Set the chart title and axis labels
axes[0].set_xlabel("Annual income (<= $150,000 per year)")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Annual income (<= $150,000 per year) by Loan status")

# Create the histogram using seaborn for "Annual Income"
sns.histplot(data=data[data.annual_inc <= 150000], x="annual_inc", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Annual Income (<= $150,000 per year)")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Annual Income (<= $150,000 per year) by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
print(data.loc[(data.annual_inc <= 150000) , 'loan_status'].value_counts())
print(data.loc[(data.annual_inc > 150000) & (data.annual_inc < 1000000) , 'loan_status'].value_counts())
print(data.loc[data.annual_inc >= 1000000, 'loan_status'].value_counts())
# Out:
# Fully Paid     302581
# Charged Off     75118
# Name: loan_status, dtype: int64
# Fully Paid     15711
# Charged Off     2545
# Name: loan_status, dtype: int64
# Fully Paid     65
# Charged Off    10
# Name: loan_status, dtype: int64

# %% [markdown]
# ## `dti (Debt-to-Income Ratio)`
# > อัตราส่วนที่คำนวณโดยใช้ยอดชำระหนี้ไม่รวมค่าจดจำนองและเงินกู้ LC ที่ขอ หารด้วยรายได้ต่อเดือนของผู้กู้ที่รายงานด้วยตนเอง (Debt to Income Ratio)

# %%
# Print a header
print("\nDebt to Income by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["dti"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Debt to Income by Loan Status
#                 count  mean   std  min  10%   25%   50%   75%   90%   95%  \
# loan_status
# Charged Off  77673.00 19.66 36.78 0.00 8.49 13.33 19.34 25.55 30.86 33.66
# Fully Paid  318357.00 16.82  8.50 0.00 6.61 10.87 16.34 22.29 27.77 30.82
#
#                 max
# loan_status
# Charged Off 9999.00
# Fully Paid  1622.00

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "DTI" (debt-to-income ratio) <= 50
sns.boxplot(data=data, x="dti", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("DTI (Debt-to-Income Ratio)")
axes[0].set_ylabel("Loan Status")
axes[0].set_title("Box plot: DTI by Loan status")

# Create the histogram using seaborn for "DTI" (debt-to-income ratio)
sns.histplot(data=data, x="dti", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the first subplot
axes[1].set_xlabel("DTI (Debt-to-Income Ratio)")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: DTI by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "DTI" (debt-to-income ratio) <= 50
sns.boxplot(data=data[data["dti"] <= 50], x="dti", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("DTI (Debt-to-Income Ratio) <= 50")
axes[0].set_ylabel("Loan Status")
axes[0].set_title("Box plot: DTI (<= 50) by Loan status")

# Create the histogram using seaborn for "DTI" (debt-to-income ratio) <= 50
sns.histplot(data=data[data["dti"] <= 50], x="dti", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("DTI (Debt-to-Income Ratio) <= 50")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: DTI (<= 50) by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
data[data['dti']>=40]["loan_status"].value_counts()
# Out:
# Fully Paid     200
# Charged Off     96
# Name: loan_status, dtype: int64

# %%
data[data['dti']>=50]["loan_status"].value_counts()
# Out:
# Fully Paid     26
# Charged Off     9
# Name: loan_status, dtype: int64

# %% [markdown]
# ## `emp_title` & `emp_length`
# > - `emp_title` : ตำแหน่งงานที่ผู้กู้ระบุเมื่อสมัครขอสินเชื่อ*
# > - `emp_length` : อายุงานเป็นปี ค่าที่เป็นไปได้อยู่ระหว่าง 0 ถึง 10 โดยที่ 0 หมายถึงน้อยกว่าหนึ่งปี และ 10 หมายถึง 10 ปีขึ้นไป

# %%
print("The unique value of employment is",data["emp_title"].nunique())
print(data.shape)
# Out:
# The unique value of employment is 173105
# (396030, 27)

# %%
pd.DataFrame(data["emp_title"].value_counts().head(10).reset_index())
# Out:
#               index  emp_title
# 0           Teacher       4389
# 1           Manager       4250
# 2  Registered Nurse       1856
# 3                RN       1846
# 4        Supervisor       1830
# 5             Sales       1638
# 6   Project Manager       1505
# 7             Owner       1410
# 8            Driver       1339
# 9    Office Manager       1218

# %%
data.groupby("emp_length")["loan_status"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# emp_length  loan_status
# 1 year      Charged Off   0.20
#             Fully Paid    0.80
# 10+ years   Charged Off   0.18
#             Fully Paid    0.82
# 2 years     Charged Off   0.19
#             Fully Paid    0.81
# 3 years     Charged Off   0.20
#             Fully Paid    0.80
# 4 years     Charged Off   0.19
#             Fully Paid    0.81
# 5 years     Charged Off   0.19
#             Fully Paid    0.81
# 6 years     Charged Off   0.19
#             Fully Paid    0.81
# 7 years     Charged Off   0.19
#             Fully Paid    0.81
# 8 years     Charged Off   0.20
#             Fully Paid    0.80
# 9 years     Charged Off   0.20
#             Fully Paid    0.80
# < 1 year    Charged Off   0.21
#             Fully Paid    0.79
# Name: loan_status, dtype: float64

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Create the bar plot for "Job length" by "Loan status"
order = ['< 1 year', '1 year', '2 years', '3 years', '4 years', '5 years',
         '6 years', '7 years', '8 years', '9 years', '10+ years']
sns.countplot(data=data, x="emp_length", hue="loan_status", ax=axes[0], order=order)

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("Employment Length")
axes[0].set_ylabel("Frequency")
axes[0].set_title("Bar Plot: Employment Length by Loan Status")
axes[0].set_xticklabels(order, rotation=90)

# Create the bar plot for the most common job titles
sns.barplot(x=data.emp_title.value_counts()[:30].values, y=data.emp_title.value_counts()[:30].index, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Frequency")
axes[1].set_ylabel("Job Title")
axes[1].set_title("Bar Plot: Top 30 Job Titles for Loan Applicants")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `home_ownership`
# > สถานะความเป็นเจ้าของบ้านที่ผู้กู้ระบุระหว่างการลงทะเบียนหรือได้รับจากรายงานเครดิต ได้แก่
# > - เช่า (RENT)
# > - เป็นเจ้าของ (OWN)
# > - จำนอง (MORTGAGE)
# > - อื่นๆ (OTHER)

# %%
# Update the values in the "home_ownership" column
data.loc[(data.home_ownership == "ANY") | (data.home_ownership == "NONE"), "home_ownership"] = "OTHER"

# Print the value counts
data.groupby("home_ownership")["loan_status"].value_counts(normalize=True)
# Out:
# home_ownership  loan_status
# MORTGAGE        Fully Paid    0.83
#                 Charged Off   0.17
# OTHER           Fully Paid    0.84
#                 Charged Off   0.16
# OWN             Fully Paid    0.79
#                 Charged Off   0.21
# RENT            Fully Paid    0.77
#                 Charged Off   0.23
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create a countplot using seaborn
sns.countplot(x="home_ownership", data=data, hue="loan_status")

# Set the chart title and axis labels
plt.title("Bar Chart: Home ownership by Loan status")
plt.xlabel("Home ownership")
plt.ylabel("Frequency")

# Display the plot
plt.show()

# %% [markdown]
# ## `issue_d` & `earliest_cr_line`
# > - `issue_d` : เดือนที่กู้เงิน
# > - `earliest_cr_line` : เดือนที่เปิดวงเงินสินเชื่อที่รายงานเร็วที่สุดของผู้กู้

# %%
# Convert the 'issue_d' column to datetime format
data["issue_d"] = pd.to_datetime(data["issue_d"])

# Convert the 'earliest_cr_line' column to datetime format
data['earliest_cr_line'] = pd.to_datetime(data['earliest_cr_line'])

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Create the histogram using seaborn for "Loan Issue date"
sns.histplot(data=data, x="issue_d", hue="loan_status", bins=35, ax=axes[0])

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("Loan Issue Date")
axes[0].set_ylabel("Frequency")
axes[0].set_title("Histogram: Loan Issue Date by Loan Status")

# Create the histogram using seaborn for "Earliest Credit Line"
sns.histplot(data=data, x="earliest_cr_line", hue="loan_status", bins=35, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Earliest Credit Line")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Earliest Credit Line by Loan Status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `title` & `purpose`
# > - `title` : หัวข้อของเงินกู้ที่ผู้กู้เป็นคนกำหนด
# > - `purpose` : หมวดหมู่ที่ผู้กู้จัดเตรียมไว้สำหรับการขอสินเชื่อ

# %%
data["title"] = data["title"].str.lower()

# %%
data["title"].value_counts().head(10)
# Out:
# debt consolidation           168108
# credit card refinancing       51781
# home improvement              17117
# other                         12993
# consolidation                  5583
# major purchase                 4998
# debt consolidation loan        3513
# business                       3017
# medical expenses               2820
# credit card consolidation      2638
# Name: title, dtype: int64

# %%
data.groupby("purpose")["loan_status"].value_counts(normalize=True)
# Out:
# purpose             loan_status
# car                 Fully Paid    0.87
#                     Charged Off   0.13
# credit_card         Fully Paid    0.83
#                     Charged Off   0.17
# debt_consolidation  Fully Paid    0.79
#                     Charged Off   0.21
# educational         Fully Paid    0.84
#                     Charged Off   0.16
# home_improvement    Fully Paid    0.83
#                     Charged Off   0.17
# house               Fully Paid    0.80
#                     Charged Off   0.20
# major_purchase      Fully Paid    0.84
#                     Charged Off   0.16
# medical             Fully Paid    0.78
#                     Charged Off   0.22
# moving              Fully Paid    0.77
#                     Charged Off   0.23
# other               Fully Paid    0.79
#                     Charged Off   0.21
# renewable_energy    Fully Paid    0.77
#                     Charged Off   0.23
# small_business      Fully Paid    0.71
# ...

# %%
# Create a countplot using seaborn
sns.countplot(x="purpose", data=data, hue="loan_status")

# Set the figure size
plt.figure(figsize=(9, 6))

# Set the chart title and axis labels
plt.xlabel("Purpose")
plt.ylabel("Frequency")
plt.title("Bar Chart: Purpose by Loan status")

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# ## `total_acc`
# > จำนวนบัญชีวงเงินสินเชื่อทั้งหมดในปัจจุบันที่แสดงอยู่ใน Credit file ของผู้กู้
# > - (Credit file คือ ประวัติการทำรายการต่างๆ ที่เกี่ยวกับการกู้ยืม เช่น กู้ยืมไปเท่าไร, ชำระคืนไปเท่าไร, เกรดของสินเชื่อ)

# %%
# Print a header
print("\nNumber of Total number of Credit Lines by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["total_acc"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Number of Total number of Credit Lines by Loan Status
#                 count  mean   std  min   10%   25%   50%   75%   90%   95%  \
# loan_status
# Charged Off  77673.00 24.98 11.91 2.00 11.00 16.00 23.00 32.00 41.00 47.00
# Fully Paid  318357.00 25.52 11.88 2.00 12.00 17.00 24.00 32.00 41.00 48.00
#
#                max
# loan_status
# Charged Off 151.00
# Fully Paid  150.00

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "Total credit lines"
sns.boxplot(data=data, x="total_acc", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the third subplot
axes[0].set_xlabel("Total Number of Credit Lines")
axes[0].set_ylabel("Loan Status")
axes[0].set_title("Box plot: Total Number of Credit Lines by Loan Status")

# Create the histogram using seaborn for "Total credit lines"
sns.histplot(data=data, x="total_acc", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the third subplot
axes[1].set_xlabel("Total Number of Credit Lines")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Total Number of Credit Lines by Loan Status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `open_acc`
# > จำนวนบัญชีวงเงินสินเชื่อแบบเปิดที่แสดงอยู่ใน Credit file ของผู้กู้ (จะน้อยกว่า total_acc เสมอ)
# > - (Credit file คือ ประวัติการทำรายการต่างๆ ที่เกี่ยวกับการกู้ยืม เช่น กู้ยืมไปเท่าไร, ชำระคืนไปเท่าไร, เกรดของสินเชื่อ)

# %%
data[data["total_acc"] - data["open_acc"] < 0][["open_acc", "total_acc"]]
# Out:
# Empty DataFrame
# Columns: [open_acc, total_acc]
# Index: []

# %%
# Print a header
print("\nNumber of Open Credit Lines by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["open_acc"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Number of Open Credit Lines by Loan Status
#                 count  mean  std  min  10%  25%   50%   75%   90%   95%   max
# loan_status
# Charged Off  77673.00 11.60 5.29 0.00 6.00 8.00 11.00 14.00 18.00 21.00 76.00
# Fully Paid  318357.00 11.24 5.10 0.00 6.00 8.00 10.00 14.00 18.00 21.00 90.00

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "Open credit lines"
sns.boxplot(data=data, x="open_acc", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the second subplot
axes[0].set_xlabel("Number of Open Credit Lines")
axes[0].set_ylabel("Loan Status")
axes[0].set_title("Box plot: Loan Status by Number of Open Credit Lines")

# Create the histogram using seaborn for "Open credit lines"
sns.histplot(data=data, x="open_acc", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Number of Open Credit Lines")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Loan Status by Number of Open Credit Lines")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `revol_bal`
# > ยอดคงเหลือหมุนเวียนของเครดิตทั้งหมด

# %%
print(data.shape)
print(data[data.revol_bal > 250000].shape)
# Out:
# (396030, 27)
# (397, 27)

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "Total credit revolving balance"
sns.boxplot(data=data, x="revol_bal", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("Total Credit Revolving Balance")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Total Credit Revolving Balance by Loan Status")

# Create the histogram using seaborn for "Total credit revolving balance"
sns.histplot(data=data, x="revol_bal", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the first subplot
axes[1].set_xlabel("Total Credit Revolving Balance")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Total Credit Revolving Balance by Loan Status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "Total credit revolving balance < 250000"
sns.boxplot(data=data[data["revol_bal"] < 100000], x="revol_bal", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the second subplot
axes[0].set_xlabel("Total Credit Revolving Balance (<100,000)")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Total Credit Revolving Balance (<100,000) by Loan Status")

# Create the histogram using seaborn for "Total credit revolving balance < 250000"
sns.histplot(data=data[data["revol_bal"] < 100000], x="revol_bal", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Total Credit Revolving Balance (<100,000)")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Total Credit Revolving Balance (<100,000) by Loan Status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `revol_util`
# > อัตราการใช้วงเงินหมุนเวียนหรือจำนวนเครดิตที่ผู้กู้ใช้เทียบกับสินเชื่อหมุนเวียนที่มีอยู่ทั้งหมด

# %%
# Print a header
print("\nRevolving Line Utilization Rate by Loan Status\n")

# Group the data by "loan_status" and calculate descriptive statistics for the "installment" column
data.groupby(by="loan_status")["total_acc"].describe(percentiles = [0.10, 0.25, 0.50, 0.75, 0.90, 0.95])
# Out:
# Revolving Line Utilization Rate by Loan Status
#                 count  mean   std  min   10%   25%   50%   75%   90%   95%  \
# loan_status
# Charged Off  77673.00 24.98 11.91 2.00 11.00 16.00 23.00 32.00 41.00 47.00
# Fully Paid  318357.00 25.52 11.88 2.00 12.00 17.00 24.00 32.00 41.00 48.00
#
#                max
# loan_status
# Charged Off 151.00
# Fully Paid  150.00

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "Revolving line utilization rate"
sns.boxplot(data=data, x="revol_util", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the first subplot
axes[0].set_xlabel("Revolving Line Utilization Rate")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Revolving Line Utilization Rate by Loan status")

# Create the histogram using seaborn for "Revolving line utilization rate"
sns.histplot(data=data, x="revol_util", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the first subplot
axes[1].set_xlabel("Revolving Line Utilization Rate")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Revolving Line Utilization Rate by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
data[data.revol_util > 200].shape
# Out:
# (1, 27)

# %%
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 6))

# Create the Box plot using seaborn for "Revolving line utilization rate < 120"
sns.boxplot(data=data[data["revol_util"] < 120], x="revol_util", y="loan_status", ax=axes[0])

# Set the chart title and axis labels for the second subplot
axes[0].set_xlabel("Revolving Line Utilization Rate < 120")
axes[0].set_ylabel("Loan status")
axes[0].set_title("Box plot: Revolving Line Utilization Rate (<120) by Loan status")

# Create the histogram using seaborn for "Revolving line utilization rate < 120"
sns.histplot(data=data[data["revol_util"] < 120], x="revol_util", hue="loan_status", bins=50, ax=axes[1])

# Set the chart title and axis labels for the second subplot
axes[1].set_xlabel("Revolving Line Utilization Rate < 120")
axes[1].set_ylabel("Frequency")
axes[1].set_title("Histogram: Revolving Line Utilization Rate (<120) by Loan status")

# Adjust spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## `initial_list_status`
# > สถานะรายการเริ่มต้นของสินเชื่อ ได้แก่ W และ F

# %%
data.groupby("initial_list_status")["loan_status"].value_counts(normalize=True)
# Out:
# initial_list_status  loan_status
# f                    Fully Paid    0.81
#                      Charged Off   0.19
# w                    Fully Paid    0.80
#                      Charged Off   0.20
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the countplot using seaborn for "Fully Paid" loans
sns.countplot(data=data[data["loan_status"]=="Fully Paid"], x="initial_list_status", alpha=0.5, color="red")

# Create the countplot using seaborn for "Charged Off" loans
sns.countplot(data=data[data["loan_status"]=="Charged Off"], x="initial_list_status", alpha=0.5, color="blue")

# Set the chart title and axis labels
plt.xlabel("Initial Listing Status of the Loan")
plt.ylabel("Frequency")
plt.title("Initial Listing Status of the Loan by Loan Status")

# Display the plot
plt.show()

# %% [markdown]
# ## `application_type`
# > รูปแบบการชำระเงินของสินเชื่อ
# > - ขอสินเชื่อบุคคล (Individual)
# > - สมัครร่วมกับผู้กู้ร่วม 2 คน (Joint)
# > - ระบบการชำระเงินออนไลน์โดยหักเงินจากบัญชีอัตโนมัติ (Direct pay)

# %%
data.groupby("application_type")["loan_status"].value_counts(normalize=True)
# Out:
# application_type  loan_status
# DIRECT_PAY        Fully Paid    0.64
#                   Charged Off   0.36
# INDIVIDUAL        Fully Paid    0.80
#                   Charged Off   0.20
# JOINT             Fully Paid    0.87
#                   Charged Off   0.13
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the countplot using seaborn for "Fully Paid" loans
sns.countplot(data=data[data["loan_status"]=="Fully Paid"], x="application_type", alpha=0.5, color="red")

# Create the countplot using seaborn for "Charged Off" loans
sns.countplot(data=data[data["loan_status"]=="Charged Off"], x="application_type", alpha=0.5, color="blue")

# Set the chart title and axis labels
plt.xlabel("Application Type")
plt.ylabel("Frequency")
plt.title("Loan Status by Application Type")

# Display the plot
plt.show()

# %% [markdown]
# ## `mort_acc`
# > จำนวนบัญชีที่ใช้อสังหาริมทรัพย์ในการจำนองเพื่อขอกู้สินเชื่อ

# %%
data.groupby("mort_acc")["loan_status"].value_counts(normalize=True).head(16)
# Out:
# mort_acc  loan_status
# 0.00      Fully Paid    0.76
#           Charged Off   0.24
# 1.00      Fully Paid    0.80
#           Charged Off   0.20
# 2.00      Fully Paid    0.81
#           Charged Off   0.19
# 3.00      Fully Paid    0.83
#           Charged Off   0.17
# 4.00      Fully Paid    0.83
#           Charged Off   0.17
# 5.00      Fully Paid    0.84
#           Charged Off   0.16
# 6.00      Fully Paid    0.84
#           Charged Off   0.16
# 7.00      Fully Paid    0.85
#           Charged Off   0.15
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the countplot using seaborn for "Fully Paid" loans
sns.countplot(data=data[data["loan_status"]=="Fully Paid"], x="mort_acc", alpha=0.5, color="red")

# Create the countplot using seaborn for "Charged Off" loans
sns.countplot(data=data[data["loan_status"]=="Charged Off"], x="mort_acc", alpha=0.5, color="blue")

# Set the chart title and axis labels
plt.xlabel("Mortgage Accounts")
plt.ylabel("Frequency")
plt.title("Loan Status by Mortgage Accounts")
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# ## `pub_rec`
# > จำนวนบันทึกสาธารณะที่เสื่อมเสีย

# %%
data.groupby("pub_rec")["loan_status"].value_counts(normalize=True).head(20)
# Out:
# pub_rec  loan_status
# 0.00     Fully Paid    0.81
#          Charged Off   0.19
# 1.00     Fully Paid    0.79
#          Charged Off   0.21
# 2.00     Fully Paid    0.77
#          Charged Off   0.23
# 3.00     Fully Paid    0.78
#          Charged Off   0.22
# 4.00     Fully Paid    0.72
#          Charged Off   0.28
# 5.00     Fully Paid    0.76
#          Charged Off   0.24
# 6.00     Fully Paid    0.75
#          Charged Off   0.25
# 7.00     Fully Paid    0.71
#          Charged Off   0.29
# 8.00     Fully Paid    0.82
#          Charged Off   0.18
# 9.00     Fully Paid    0.58
#          Charged Off   0.42
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the countplot using seaborn for "Fully Paid" loans
sns.countplot(data=data[data["loan_status"]=="Fully Paid"], x="pub_rec", alpha=0.5, color="red")

# Create the countplot using seaborn for "Charged Off" loans
sns.countplot(data=data[data["loan_status"]=="Charged Off"], x="pub_rec", alpha=0.5, color="blue")

# Set the chart title and axis labels
plt.xlabel("Number of Derogatory Public Records")
plt.ylabel("Frequency")
plt.xticks(rotation=90)
plt.title("Loan Status by Number of Derogatory Public Records")

# Display the plot
plt.show()

# %% [markdown]
# ## `pub_rec_bankruptcies`
# > จำนวนครั้งของการล้มละลาย

# %%
data[data["pub_rec_bankruptcies"] > 1].shape
# Out:
# (2325, 27)

# %%
data.groupby("pub_rec_bankruptcies")["loan_status"].value_counts(normalize=True)
# Out:
# pub_rec_bankruptcies  loan_status
# 0.00                  Fully Paid    0.81
#                       Charged Off   0.19
# 1.00                  Fully Paid    0.80
#                       Charged Off   0.20
# 2.00                  Fully Paid    0.77
#                       Charged Off   0.23
# 3.00                  Fully Paid    0.79
#                       Charged Off   0.21
# 4.00                  Fully Paid    0.68
#                       Charged Off   0.32
# 5.00                  Fully Paid    0.84
#                       Charged Off   0.16
# 6.00                  Fully Paid    0.71
#                       Charged Off   0.29
# 7.00                  Fully Paid    0.75
#                       Charged Off   0.25
# 8.00                  Charged Off   0.50
#                       Fully Paid    0.50
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the countplot using seaborn for "Fully Paid" loans
sns.countplot(data=data[data["loan_status"]=="Fully Paid"], x="pub_rec_bankruptcies", alpha=0.5, color="red")

# Create the countplot using seaborn for "Charged Off" loans
sns.countplot(data=data[data["loan_status"]=="Charged Off"], x="pub_rec_bankruptcies", alpha=0.5, color="blue")

# Set the chart title and axis labels
plt.xlabel("Number of Public Record Bankruptcies")
plt.ylabel("Frequency")
plt.title("Loan Status by Number of Public Record Bankruptcies")

# Display the plot
plt.show()

# %% [markdown]
# # 3. Data Preparation

# %% [markdown]
# ## Handling Numerical Variable

# %%
print([column for column in data.columns if (data[column].dtype == "int64") | (data[column].dtype == "float64")])
# Out:
# ['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti', 'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc', 'mort_acc', 'pub_rec_bankruptcies']

# %%
def pub_rec(number):
    if number == 0.0:
        return 0
    else:
        return 1

def mort_acc(number):
    if number == 0.0:
        return 0
    elif number >= 1.0:
        return 1
    else:
        return number

def pub_rec_bankruptcies(number):
    if number == 0.0:
        return 0
    elif number >= 1.0:
        return 1
    else:
        return number

# %%
data['pub_rec'] = data['pub_rec'].apply(pub_rec)
data['mort_acc'] = data['mort_acc'].apply(mort_acc)
data['pub_rec_bankruptcies'] = data['pub_rec_bankruptcies'].apply(pub_rec_bankruptcies)

# %%
data.groupby("mort_acc")["loan_status"].value_counts(normalize=True).head(16)
# Out:
# mort_acc  loan_status
# 0.00      Fully Paid    0.76
#           Charged Off   0.24
# 1.00      Fully Paid    0.82
#           Charged Off   0.18
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the countplot using seaborn for "Fully Paid" loans
sns.countplot(data=data[data["loan_status"]=="Fully Paid"], x="mort_acc", alpha=0.5, color="red")

# Create the countplot using seaborn for "Charged Off" loans
sns.countplot(data=data[data["loan_status"]=="Charged Off"], x="mort_acc", alpha=0.5, color="blue")

# Set the chart title and axis labels
plt.xlabel("Mortgage Accounts")
plt.ylabel("Frequency")
plt.title("Loan Status by Mortgage Accounts")
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# ## Handling Categorical Variable

# %%
print([column for column in data.columns if data[column].dtype == object])
# Out:
# ['term', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'verification_status', 'loan_status', 'purpose', 'title', 'initial_list_status', 'application_type', 'address']

# %% [markdown]
# ### `loan_status`

# %%
data["loan_status"].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
data["loan_status"] = data["loan_status"].map({"Charged Off":1, "Fully Paid":0})
data["loan_status"].sample(10)
# Out:
# 302856    0
# 111859    1
# 35542     0
# 295493    0
# 388740    0
# 261125    1
# 270461    0
# 274746    0
# 150344    0
# 21994     0
# Name: loan_status, dtype: int64

# %% [markdown]
# ### `term`

# %%
data["term"].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
data["term"] = data["term"].map({' 36 months': 36, ' 60 months': 60})
data["term"].sample(10)
# Out:
# 222230    36
# 141197    36
# 22096     60
# 241983    36
# 229575    36
# 305316    36
# 72461     36
# 255079    60
# 176004    36
# 331318    36
# Name: term, dtype: int64

# %% [markdown]
# ### `earliest_cr_line`

# %%
data['earliest_cr_line'] = data['earliest_cr_line'].dt.year
data['earliest_cr_line'].sample(10)
# Out:
# 4784      1989
# 229112    1984
# 134956    1997
# 78735     2000
# 24326     1999
# 177425    2008
# 176260    1999
# 341885    1994
# 151761    1998
# 176083    1992
# Name: earliest_cr_line, dtype: int64

# %% [markdown]
# ### `address and generate new variable is zip_code`

# %%
data.address.head()
# Out:
# 0       0174 Michelle Gateway\r\nMendozaberg, OK 22690
# 1    1076 Carney Fort Apt. 347\r\nLoganmouth, SD 05113
# 2    87025 Mark Dale Apt. 269\r\nNew Sabrina, WV 05113
# 3              823 Reid Ford\r\nDelacruzside, MA 00813
# 4               679 Luna Roads\r\nGreggshire, VA 11650
# Name: address, dtype: object

# %%
data['zip_code'] = data.address.apply(lambda x: x[-5:])
data['zip_code'] = data['zip_code'].astype("object")

# %%
data.groupby("zip_code")["loan_status"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# zip_code  loan_status
# 00813     0             1.00
# 05113     0             1.00
# 11650     1             1.00
# 22690     0             0.81
#           1             0.19
# 29597     0             1.00
# 30723     0             0.81
#           1             0.19
# 48052     0             0.80
#           1             0.20
# 70466     0             0.80
#           1             0.20
# 86630     1             1.00
# 93700     1             1.00
# Name: loan_status, dtype: float64

# %%
# Set the figure size
plt.figure(figsize=(9, 6))

# Create the bar chart using seaborn
sns.countplot(data=data.sort_values("zip_code"), x="zip_code", hue="loan_status")

# Set the chart title and axis labels
plt.xlabel("Zip code")
plt.ylabel("Frequency")
plt.title("Bar plot: Zip code by loan status")
plt.legend(labels=['Fully Paid: 0', 'Charge Off: 1'])

# Display the plot
plt.show()

# %% [markdown]
# ## Change Data type from objects to category for Feature Selections

# %%
def convert_obj_columns_to_category(df):
    for c in df.columns:
        col_type = df[c].dtype
        if col_type == 'object' or col_type.name == 'category':
            df[c] = df[c].astype('category')
    return df

convert_obj_columns_to_category(data)
# Out:
#         loan_amnt  term  int_rate  installment grade sub_grade  \
# 0        10000.00    36     11.44       329.48     B        B4
# 1         8000.00    36     11.99       265.68     B        B5
# 2        15600.00    36     10.49       506.97     B        B3
# 3         7200.00    36      6.49       220.65     A        A2
# 4        24375.00    60     17.27       609.33     C        C5
# ...           ...   ...       ...          ...   ...       ...
# 396025   10000.00    60     10.99       217.38     B        B4
# 396026   21000.00    36     12.29       700.42     C        C1
# 396027    5000.00    36      9.99       161.32     B        B1
# 396028   21000.00    60     15.31       503.02     C        C2
# 396029    2000.00    36     13.61        67.98     C        C2
#
#                        emp_title emp_length home_ownership  annual_inc  \
# 0                      Marketing  10+ years           RENT   117000.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 28 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  int64
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  category
#  5   sub_grade             396030 non-null  category
#  6   emp_title             373103 non-null  category
#  7   emp_length            377729 non-null  category
#  8   home_ownership        396030 non-null  category
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  category
#  11  issue_d               396030 non-null  datetime64[ns]
#  12  loan_status           396030 non-null  int64
#  13  purpose               396030 non-null  category
# ...

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# ### `Number and Percentage of Missing value`

# %%
# Calculate the fractions of missing values
missing_sumations = pd.DataFrame(data.isnull().sum(), columns=["Missing Sum"]) \
                    .sort_values(by="Missing Sum",ascending=False)

# Calculate the fractions of missing values
missing_fractions = pd.DataFrame(data.isnull().sum(), columns=['Missing Percentage']) \
                   	.apply(lambda x: round((x/data.shape[0])*100, 4), axis=1) \
                    .sort_values(by="Missing Percentage" ,ascending=False)

missing_tb = pd.merge(missing_sumations, missing_fractions, left_index=True, right_index=True)
missing_tb.head(10)
# Out:
#                       Missing Sum  Missing Percentage
# mort_acc                    37795                9.54
# emp_title                   22927                5.79
# emp_length                  18301                4.62
# title                        1755                0.44
# pub_rec_bankruptcies          535                0.14
# revol_util                    276                0.07
# dti                             0                0.00
# address                         0                0.00
# application_type                0                0.00
# initial_list_status             0                0.00

# %% [markdown]
# ### `Imputing the missing value`

# %%
data["mort_acc"] = data["mort_acc"].fillna(data["mort_acc"].median())
data["revol_util"] = data["revol_util"].fillna(data["revol_util"].median())
data["pub_rec_bankruptcies"] = data["pub_rec_bankruptcies"].fillna(data["pub_rec_bankruptcies"].median())

# %% [markdown]
# ### `Remove the missing value`

# %%
# print("Before drop missing values :", str(data.shape))
# data.dropna(subset=["pub_rec_bankruptcies", "revol_util"], inplace=True)
# print("After drop missing values :", str(data.shape))

# %% [markdown]
# ## Drop Variables

# %%
data.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'application_type',
#        'mort_acc', 'pub_rec_bankruptcies', 'address', 'zip_code'],
#       dtype='object')

# %%
data[['term', 'grade', 'sub_grade', 'emp_title',
      'emp_length', 'home_ownership', 'verification_status',
      'purpose', 'title', 'initial_list_status', 'application_type',
      'address']].nunique().sort_values(ascending=False)
# Out:
# address                393700
# emp_title              173105
# title                   41327
# sub_grade                  35
# purpose                    14
# emp_length                 11
# grade                       7
# home_ownership              4
# verification_status         3
# application_type            3
# term                        2
# initial_list_status         2
# dtype: int64

# %%
data.groupby("emp_length")["loan_status"].value_counts(normalize=True).sort_index(ascending=True)
# Out:
# emp_length  loan_status
# 1 year      0             0.80
#             1             0.20
# 10+ years   0             0.82
#             1             0.18
# 2 years     0             0.81
#             1             0.19
# 3 years     0             0.80
#             1             0.20
# 4 years     0             0.81
#             1             0.19
# 5 years     0             0.81
#             1             0.19
# 6 years     0             0.81
#             1             0.19
# 7 years     0             0.81
#             1             0.19
# 8 years     0             0.80
#             1             0.20
# 9 years     0             0.80
#             1             0.20
# < 1 year    0             0.79
#             1             0.21
# Name: loan_status, dtype: float64

# %%
print(data["title"].value_counts().head(),"\n")
print(data["purpose"].value_counts().head())

# Purpose values like to title values
# Out:
# debt consolidation         168108
# credit card refinancing     51781
# home improvement            17117
# other                       12993
# consolidation                5583
# Name: title, dtype: int64
#
# debt_consolidation    234507
# credit_card            83019
# home_improvement       24030
# other                  21185
# major_purchase          8790
# Name: purpose, dtype: int64

# %%
drop_list = ["grade", "emp_title", "title", "address", "issue_d", "emp_length"]
data.drop(drop_list, axis=1, inplace=True)

# %% [markdown]
# ## Check duplicate rows

# %%
data.duplicated().any()
# Out:
# False

# %%
print(f"Data shape: {data.shape}")

# Remove Duplicate Rows
data.drop_duplicates(inplace=True)

print(f"Data shape: {data.shape}")
# Out:
# Data shape: (396030, 22)
# Data shape: (396030, 22)

# %% [markdown]
# ## Train Test Split

# %%
# Splitting data into train and test sets
train, test = train_test_split(data, test_size=0.33, random_state=42)
print("Train shape is", train.shape)
print("Test shape is", test.shape)
# Out:
# Train shape is (265340, 22)
# Test shape is (130690, 22)

# %% [markdown]
# ## Outlier Handling (Outliers Detection and Removing)

# %%
outlier_detec = ["loan_amnt", "installment",
                 "int_rate", "annual_inc",
                 "dti",
                 "total_acc", "open_acc",
                 "revol_bal","revol_util"]

print("Shape of Data Remaining is", train.shape)
for i in outlier_detec:
    print("berfore removing outlier of", i, "is", train.shape)
    q1 = train[i].quantile(0.25)
    q3 = train[i].quantile(0.75)
    iqr = q3 - q1
    train = train[(train[i] < (train[i].mean() + 3*train[i].std())) &
                  (train[i] > (train[i].mean() - 3*train[i].std()))]
    print("after removing outlier of", i, "is", train.shape)
    print("==============================================================\n")
# Out:
# Shape of Data Remaining is (265340, 22)
# berfore removing outlier of loan_amnt is (265340, 22)
# after removing outlier of loan_amnt is (265212, 22)
# ...
#
# berfore removing outlier of installment is (265212, 22)
# after removing outlier of installment is (261868, 22)
# ...
#
# berfore removing outlier of int_rate is (261868, 22)
# after removing outlier of int_rate is (261362, 22)
# ...
#
# berfore removing outlier of annual_inc is (261362, 22)
# after removing outlier of annual_inc is (258960, 22)
# ...
#
# berfore removing outlier of dti is (258960, 22)
# after removing outlier of dti is (258954, 22)
# ...
#
# berfore removing outlier of total_acc is (258954, 22)
# after removing outlier of total_acc is (256482, 22)
# ...
#
# berfore removing outlier of open_acc is (256482, 22)
# after removing outlier of open_acc is (253486, 22)
# ...
#
# berfore removing outlier of revol_bal is (253486, 22)
# after removing outlier of revol_bal is (250126, 22)
# ...
#
# berfore removing outlier of revol_util is (250126, 22)
# ...

# %% [markdown]
# ## X_tran y_train X_test y_test Split

# %%
X_train, y_train = train.drop('loan_status', axis=1), train.loan_status
X_test, y_test = test.drop('loan_status', axis=1), test.loan_status

# %% [markdown]
# ## Data Normalization

# %%
scaler = MinMaxScaler()

scale_col = list([column for column in X_train.columns if
                  (data[column].dtype == "int32") |
                  (data[column].dtype == "int64") |
                  (data[column].dtype == "float64")])

X_train[scale_col] = scaler.fit_transform(X_train[scale_col])
X_test[scale_col] = scaler.transform(X_test[scale_col])

# %% [markdown]
# ## Features Selection (Features Importance)

# %% [markdown]
# ### `Lightgbm Modeling for Feature Selections`

# %%
params = {
    'objective': 'binary',
    'metric': 'binary_logloss',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.001,
    'verbose': -1
}

# Train the model using lgb.LGBMClassifier() or lgb.train
model = lgb.LGBMClassifier(**params, random_state = 42)  # Or use lgb.train with lgb.Dataset and train_data

# Train the model
model.fit(X_train, y_train)

# Get feature importances from the model
feature_importances = model.feature_importances_

# Create a DataFrame with feature names and their corresponding importances
importance_lgb = pd.DataFrame({'feature': X_train.columns, 'importance': feature_importances})

# Sort features by importance in descending order
importance_lgb = importance_lgb.sort_values(by='importance', ascending=False)

# Plotting the feature importances using scikit-learn's plot_importance function
plt.figure(figsize=(10, 6))
lgb.plot_importance(model, max_num_features=30)  # Plotting the top 10 most important features
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.show()

# %% [markdown]
# ### `Selection`

# %%
importance_lgb_list = importance_lgb["feature"][importance_lgb["importance"] > 100]
X_train = X_train[importance_lgb_list]
X_test = X_test[importance_lgb_list]

# %%
importance_lgb_list
# Out:
# 1               term
# 4          sub_grade
# 6         annual_inc
# 9                dti
# 18          mort_acc
# 5     home_ownership
# 2           int_rate
# 20          zip_code
# 3        installment
# Name: feature, dtype: object

# %% [markdown]
# ##  Encoding by One Hot Encoding (After Features Selection)
#
# Encoding แยกกันแล้ว ลักษณะข้อมูลจะหน้าตาเหมือนกันไหม??
# หรือควรใช้ encoding ของ sklearn

# %%
# dummies = list([column for column in data.columns if (data[column].dtype == "object")])
# data = pd.get_dummies(data, columns=dummies, drop_first=True)

dummies = list([column for column in X_train.columns if (X_train[column].dtype == "category")])
print(dummies)
X_train = pd.get_dummies(X_train, columns=dummies, drop_first=True)
X_test = pd.get_dummies(X_test, columns=dummies, drop_first=True)
# Out:
# ['sub_grade', 'home_ownership', 'zip_code']

# %% [markdown]
# ## Imbalance (in modeling pipeline)

# %%
# from imblearn.over_sampling import SMOTE
# from collections import Counter
# print('Original dataset shape %s' % Counter(y_train))
# rus = SMOTE(random_state=0, sampling_strategy=0.3)
# X_resampled, y_resampled = rus.fit_resample(X_train, y_train)
# print('Resampled dataset shape %s' % Counter(y_resampled))

# %%
# from imblearn.under_sampling import RandomUnderSampler
# from collections import Counter
# print('Original dataset shape %s' % Counter(y_train))
# rus = RandomUnderSampler(random_state=0, sampling_strategy=0.3)
# X_resampled, y_resampled = rus.fit_resample(X_train, y_train)
# print('Resampled dataset shape %s' % Counter(y_resampled))

# %% [markdown]
# # 4. Modeling

# %% [markdown]
# ## LightGBM-Classifier
# (Light Gradient Boosting Machine-Classifier)

# %% [markdown]
# ### Training Model

# %%
# Create the LightGBM classifier
lgb_model = lgb.LGBMClassifier(objective='binary',
                               class_weight='balanced')

# Define the hyperparameters for the LightGBM model
# param_lgb = {
#     'lightGBM__n_estimators': [100, 200, 300],
#     'lightGBM__learning_rate': [0.01, 0.05, 0.1],
#     'lightGBM__max_depth': [5, 10, -1],
#     'lightGBM__num_leaves': [31, 63, 127]
# }

# Create the pipeline with SMOTE(Over-Sampling), RandomOverSampler(Under-Sampling), and LightGBM
pipeline_lgb = Pipeline([
    # ('smote', SMOTE(random_state=42, sampling_strategy=0.5)),
    ('under_sampler', RandomUnderSampler(random_state=42, sampling_strategy=0.3)),
    ('lightGBM', lgb_model)
])

# # Create the GridSearchCV object
# grid_lgb = GridSearchCV(pipeline_lgb, param_lgb, cv=10, scoring='roc_auc', n_jobs=-1)

# Train the GridSearchCV model with Imbalance data on X_train and y_train
# grid_lgb.fit(X_train, y_train)
pipeline_lgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('under_sampler',
#                  RandomUnderSampler(random_state=42, sampling_strategy=0.3)),
#                 ('lightGBM',
#                  LGBMClassifier(class_weight='balanced', objective='binary'))])

# %% [markdown]
# ### Evaluate the model

# %%
# # Get the best parameters and the best model
# best_params_lgb = grid_lgb.best_params_
# print("Best Parameters:", best_params_lgb)

# %%
# best_model_lgb = grid_lgb.best_estimator_
# print(best_model_lgb)

# %% [markdown]
# #### `Confusion Matrix`

# %%
# #cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay.from_predictions(
#     best_model_lgb, X_test, y_test,
#     cmap='Blues', values_format='d',
#     display_labels=['Fully Paid: 0','Change Off: 1']
# )
# plt.title("Confusion Matrix", size=20)
# plt.show()

#cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay.from_estimator(
    pipeline_lgb, X_test, y_test,
    cmap='Blues', values_format='d',
    display_labels=['Fully Paid: 0','Change Off: 1']
)
plt.title("Confusion Matrix", size=20)
plt.show()

# %% [markdown]
# #### `Classification Report and Check Overfitting`

# %%
# print("Classification Report of Train Data:")
# print(classification_report(y_test, best_model_lgb.predict(X_test)))

print("Classification Report of Train Data:")
print(classification_report(y_train, pipeline_lgb.predict(X_train)))
# Out:
# Classification Report of Train Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87    201174
#            1       0.51      0.82      0.63     48945
#
#     accuracy                           0.81    250119
#    macro avg       0.73      0.81      0.75    250119
# weighted avg       0.86      0.81      0.82    250119

# %%
# print("Classification Report of Test Data:")
# print(classification_report(y_test, best_model_lgb.predict(X_test)))

print("Classification Report of Test Data:")
print(classification_report(y_test, pipeline_lgb.predict(X_test)))
# Out:
# Classification Report of Test Data:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.87    104951
#            1       0.50      0.80      0.61     25739
#
#     accuracy                           0.80    130690
#    macro avg       0.72      0.80      0.74    130690
# weighted avg       0.85      0.80      0.82    130690

# %% [markdown]
# #### `ROC-AUC Score and Curve`

# %%
# auc_score_lgb = roc_auc_score(y_test, best_model_lgb.predict_proba(X_test)[:, 1])
# print(f"AUC Score: {auc_score_lgb:.4f}")

auc_score_lgb = roc_auc_score(y_test, pipeline_lgb.predict_proba(X_test)[:, 1])
print(f"AUC Score: {auc_score_lgb:.4f}")
# Out:
# AUC Score: 0.9050

# %%
# RocCurveDisplay.from_estimator(best_model_lgb, X_test, y_test)
# plt.title('Receiver Operating Characteristic (ROC) Curve')
# plt.show()

RocCurveDisplay.from_estimator(pipeline_lgb, X_test, y_test)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %% [markdown]
# ## XGboost-Classifier
# (Extreme Gradient Boosting-Classifier)

# %% [markdown]
# ### Training Model

# %%
# Create the XGboost classifier
xgb_model = xgb.XGBClassifier(objective='binary:logistic', random_state=42)

# Define the hyperparameters for the XGboost model
# param_xgb = {
#     'xgb__n_estimators': [100, 200, 300],
#     'xgb__learning_rate': [0.01, 0.05, 0.1],
#     'xgb__max_depth': [5, 10, -1],
# }

# Create the pipeline with SMOTE(Over-Sampling), RandomOverSampler(Under-Sampling), and XGboost
pipeline_xgb = Pipeline([
    # ('smote', SMOTE(random_state=42, sampling_strategy=0.5)),
    ('under_sampler', RandomUnderSampler(random_state=42, sampling_strategy=1)),
    ('xgb', xgb_model),
])

# Create the GridSearchCV object
# grid_xgb = GridSearchCV(pipeline_xgb, param_xgb, cv=10, scoring='roc_auc', n_jobs=-1)

# Train the GridSearchCV model with Imbalance data on X_train and y_train
# grid_xgb.fit(X_train, y_train)
pipeline_xgb.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('under_sampler',
#                  RandomUnderSampler(random_state=42, sampling_strategy=1)),
#                 ('xgb',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
# ...

# %% [markdown]
# ### Evaluate the model

# %%
# # Get the best parameters and the best model
# best_params_xgb = grid_xgb.best_params_
# print("Best Parameters:", best_params_xgb)

# %%
# best_model_xgb = grid_xgb.best_estimator_
# print(best_model_xgb)

# %% [markdown]
# #### `Confusion Matrix`

# %%
# #cm = confusion_matrix(y_test, y_pred)
# disp = ConfusionMatrixDisplay.from_predictions(
#     best_model_xgb, X_test, y_test,
#     cmap='Blues', values_format='d',
#     display_labels=['Fully Paid: 0','Change Off: 1']
# )
# plt.title("Confusion Matrix", size=20)
# plt.show()

#cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay.from_estimator(
    pipeline_xgb, X_test, y_test,
    cmap='Blues', values_format='d',
    display_labels=['Fully Paid: 0','Change Off: 1']
)
plt.title("Confusion Matrix", size=20)
plt.show()

# %% [markdown]
# #### `Classification Report and Check Overfitting`

# %%
# print("Classification Report of Train Data:")
# print(classification_report(y_test, best_model_xgb.predict(X_test)))

print("Classification Report of Train Data:")
print(classification_report(y_train, pipeline_xgb.predict(X_train)))
# Out:
# Classification Report of Train Data:
#               precision    recall  f1-score   support
#
#            0       0.95      0.81      0.87    201174
#            1       0.51      0.83      0.63     48945
#
#     accuracy                           0.81    250119
#    macro avg       0.73      0.82      0.75    250119
# weighted avg       0.87      0.81      0.83    250119

# %%
# print("Classification Report of Test Data:")
# print(classification_report(y_test, best_model_xgb.predict(X_test)))

print("Classification Report of Test Data:")
print(classification_report(y_test, pipeline_xgb.predict(X_test)))
# Out:
# Classification Report of Test Data:
#               precision    recall  f1-score   support
#
#            0       0.94      0.80      0.86    104951
#            1       0.49      0.80      0.61     25739
#
#     accuracy                           0.80    130690
#    macro avg       0.72      0.80      0.74    130690
# weighted avg       0.85      0.80      0.81    130690

# %% [markdown]
# #### `ROC-AUC Score and Curve`

# %%
# auc_score_xgb = roc_auc_score(y_test, best_model_xgb.predict_proba(X_test)[:, 1])
# print(f"AUC Score: {auc_score_xgb:.4f}")

auc_score_xgb = roc_auc_score(y_test, pipeline_xgb.predict_proba(X_test)[:, 1])
print(f"AUC Score: {auc_score_xgb:.4f}")
# Out:
# AUC Score: 0.9029

# %%
# RocCurveDisplay.from_estimator(best_model_xgb, X_test, y_test)
# plt.title('Receiver Operating Characteristic (ROC) Curve')
# plt.show()

RocCurveDisplay.from_estimator(pipeline_xgb, X_test, y_test)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()

# %% [markdown]
# ## Random Forest-Classifier

# %% [markdown]
# ### Training Model

# %%
# Create the Random Forest model
rf_model = RandomForestClassifier(random_state=42)

# Create the pipeline with SMOTE(Over-Sampling), RandomOverSampler(Under-Sampling), and Random Forest
pipeline_rf = Pipeline([
    # ('smote', SMOTE(random_state=42, sampling_strategy=0.5)),
    ('under_sampler', RandomUnderSampler(random_state=42, sampling_strategy=1)),
    ('rf', rf_model),
])

# Train the GridSearchCV model with Imbalance data on X_train and y_train
pipeline_rf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('under_sampler',
#                  RandomUnderSampler(random_state=42, sampling_strategy=1)),
#                 ('rf', RandomForestClassifier(random_state=42))])

# %% [markdown]
# ### Evaluate the model

# %% [markdown]
# #### `Confusion Matrix`

# %%
#cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay.from_estimator(
    pipeline_rf, X_test, y_test,
    cmap='Blues', values_format='d',
    display_labels=['Fully Paid: 0','Change Off: 1']
)
plt.title("Confusion Matrix", size=20)
plt.show()

# %% [markdown]
# #### `Classification Report and Check Overfitting`

# %%
print("Classification Report of Train Data:")
print(classification_report(y_train, pipeline_rf.predict(X_train)))
# Out:
# Classification Report of Train Data:
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92    201174
#            1       0.62      1.00      0.77     48945
#
#     accuracy                           0.88    250119
#    macro avg       0.81      0.93      0.84    250119
# weighted avg       0.93      0.88      0.89    250119

# %%
print("Classification Report of Test Data:")
print(classification_report(y_test, pipeline_rf.predict(X_test)))
# Out:
# Classification Report of Test Data:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86    104951
#            1       0.49      0.77      0.60     25739
#
#     accuracy                           0.80    130690
#    macro avg       0.71      0.79      0.73    130690
# weighted avg       0.85      0.80      0.81    130690

# %% [markdown]
# #### `ROC-AUC Score and Curve`

# %%
auc_score_rf = roc_auc_score(y_test, pipeline_rf.predict_proba(X_test)[:, 1])
print(f"AUC Score: {auc_score_rf:.4f}")
# Out:
# AUC Score: 0.8890

# %%
RocCurveDisplay.from_estimator(pipeline_rf, X_test, y_test)
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()
