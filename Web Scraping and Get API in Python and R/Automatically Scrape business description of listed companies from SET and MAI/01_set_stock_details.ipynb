# %%
# import os
# os.system("pip install  selenium")
# os.system("pip install  beautifulsoup4")
# os.system("pip install  requests")

# %%
import sys
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
import chromedriver_autoinstaller
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # 1. Get sector name in SET market

# %%
# options = webdriver.ChromeOptions()
# options.add_argument("--start-maximized")
# options.add_argument("--headless=new")
# driver = webdriver.Chrome(options)
# driver.get('https://www.set.or.th/th/market/index/set/overview')
# time.sleep(5)

# try:
#     click_out = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/div/div[1]/button')
#     click_out.click()
# except:
#     print("can't close this element")

# click_out_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[7]/div/div/div[2]/button')
# click_out_2.click()

# # Find the table using its XPath
# table_element = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/table')

# # Get the HTML content of the table
# table_html = table_element.get_attribute('outerHTML')

# driver.close()

# # Parse the HTML content with BeautifulSoup
# soup = BeautifulSoup(table_html, 'html.parser').find_all('tbody')[0]

# # Find all table rows including headers
# table_rows = soup.find_all('tr', {'aria-labelledby':'accordion-heading'})

# # Extract industry name from table
# sector_names = [row.find_all("span")[0].text.lower() for row in table_rows]
# print(sector_names)

# %%
sector_names = ['agri',
 'food',
 'fashion',
 'home',
 'person',
 'bank',
 'fin',
 'insur',
 'auto',
 'imm',
 'paper',
 'petro',
 'pkg',
 'steel',
 'conmat',
 'prop',
 'pf&reit',
 'cons',
 'energ',
 'mine',
 'comm',
 'helth',
 'media',
 'prof',
 'tourism',
 'trans',
 'etron',
 'ict']

# %% [markdown]
# # 2. Get name of stocks from each industry

# %%
all_symbol_sector = []
for sector_name in sector_names:
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options)
    driver.get(f'https://www.set.or.th/th/market/index/set/{sector_name}')
    time.sleep(5)
    
    try:
        click_out = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/div/div[1]/button')
        click_out.click()
        # time.sleep(2)
    except:
        pass

    click_out_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[7]/div/div/div[2]/button')
    click_out_2.click()
    # time.sleep(2)
    
    try:
        # Find the table using its XPath
        table_element = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/div/div[2]/table')

        # Get the HTML content of the table
        table_html = table_element.get_attribute('outerHTML')
        
        driver.close()

        # Parse the HTML content with BeautifulSoup
        soup = BeautifulSoup(table_html, 'html.parser').find_all('tbody')[0]
            
        table_rows = soup.find_all('tr')

        # Extract industry name from table
        symbol_sector = [[sector_name, row.find_all("div", {'class':'symbol pt-1'})[0].text.replace('\n','').strip().lower()] for row in table_rows]
            
        all_symbol_sector += symbol_sector
    except:
        print(f"{sector_name} do not has a table")
    
df = pd.DataFrame(all_symbol_sector, columns=["sector_name", "stock_name"])
df
# Out:
# mine do not has a table
#     sector_name stock_name
# 0          agri         ee
# 1          agri       gfpt
# 2          agri        lee
# 3          agri        ner
# 4          agri       pppm
# ..          ...        ...
# 694         ict      synex
# 695         ict      thcom
# 696         ict        tkc
# 697         ict       true
# 698         ict        twz
#
# [699 rows x 2 columns]

# %%
df.to_csv('set_stock_symbol.csv', index=False)

# %%
df = pd.read_csv('set_stock_symbol.csv')
df.tail()
# Out:
#     sector_name stock_name
# 694         ict      synex
# 695         ict      thcom
# 696         ict        tkc
# 697         ict       true
# 698         ict        twz

# %% [markdown]
# # 3. Get business description, website, and one report zip link of each stock

# %%
all_symbol_detail = []
for sector, symbol in zip(df["sector_name"].to_list(), df["stock_name"].to_list()):
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options)
    driver.get(f'https://www.set.or.th/th/market/product/stock/quote/{symbol}/company-profile/information')
    # time.sleep(2)
    
    try:
        click_out = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/div/div[1]/button')
        click_out.click()
    except:
        pass

    try:
        click_out_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[7]/div/div/div[2]/button')
        click_out_2.click()
    except:
        pass
    
    # time.sleep(2)

    # Find the table using its XPath and Get the HTML content of the table
    # Parse the HTML content with BeautifulSoup
    table_html_1 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/div/div/div/div[1]') \
                        .get_attribute('outerHTML')
    soup_1 = BeautifulSoup(table_html_1, 'html.parser')

    # Find the table using its XPath and Get the HTML content of the table
    # Parse the HTML content with BeautifulSoup
    table_html_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/div/div/div/div[2]/div[2]/div[1]') \
                        .get_attribute('outerHTML')
    soup_2 = BeautifulSoup(table_html_2, 'html.parser')
    
    driver.close()

    h2 = soup_1.find_all('h2')[0].text.replace('\n', '').strip()
    des = soup_1.find_all('span')[0].text.replace('\n', '').strip()
    link_website = soup_1.find_all('a')[0].text.strip()
    try:
        one_report_link = soup_2.find_all('a')[0]['href']
    except:
        one_report_link = ""
        print(f"{symbol} do not have a report")

    stock_detail = ["SET", sector.upper(), symbol.upper(), h2, des, link_website, one_report_link]
    all_symbol_detail.append(stock_detail)
# Out:
# btsgif do not have a report
# tffif do not have a report
# 3bbif do not have a report
# dif do not have a report
# spreme do not have a report

# %%
df_detail = pd.DataFrame(all_symbol_detail, columns=["market", "sector", "symbol", "symbol_name", "description", "link_website", "one_report_link"])
df_detail.tail()
# Out:
#     market sector symbol                                        symbol_name  \
# 694    SET    ICT  SYNEX           บริษัท ซินเน็ค (ประเทศไทย) จำกัด (มหาชน)
# 695    SET    ICT  THCOM                         บริษัท ไทยคม จำกัด (มหาชน)
# 696    SET    ICT    TKC  บริษัท เทิร์นคีย์ คอมมูนิเคชั่น เซอร์วิส จำกัด...
# 697    SET    ICT   TRUE              บริษัท ทรู คอร์ปอเรชั่น จำกัด (มหาชน)
# 698    SET    ICT    TWZ     บริษัท ทีดับบลิวแซด คอร์ปอเรชั่น จำกัด (มหาชน)
#
#                                            description  \
# 694  จัดจำหน่ายคอมพิวเตอร์ อุปกรณ์ต่อพ่วงคอมพิวเตอร...
# 695  บริษัทประกอบธุรกิจในกลุ่มธุรกิจหลัก 4 กลุ่ม ได...
# 696  ให้บริการออกแบบ วางระบบ จัดหาอุปกรณ์ ติดตั้ง ท...
# 697  ผู้ให้บริการด้านการสื่อสารโทรคมนาคม บริการด้าน...
# 698  ประกอบธุรกิจหลักเป็นผู้จำหน่ายและให้บริการต่าง...
#
#                     link_website  \
# 694      http://www.synnex.co.th
# 695       http://www.thaicom.net
# 696  http://www.tkc-services.com
# 697    http://www.truecorp.co.th
# 698         http://www.twz.co.th
#
#                                        one_report_link
# 694  https://weblink.set.or.th/dat/f56/0981ONE01042...
# 695  https://weblink.set.or.th/dat/f56/0380ONE22022...
# 696  https://weblink.set.or.th/dat/f56/1674ONE01042...
# 697  https://weblink.set.or.th/dat/f56/1756ONE08032...
# 698  https://weblink.set.or.th/dat/f56/0867ONE01042...

# %%
df_detail.to_csv('set_stock_details.csv', index=False, encoding='utf-8-sig')
