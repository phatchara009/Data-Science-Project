# %%
import pandas as pd
pd.set_option("display.precision", 2)

# %%
df = pd.read_excel("data/finance_data.xlsx")
df.head()
# Out:
#                Indicator Name  2019-01-01 00:00:00  2019-02-01 00:00:00  \
# 0                      Income             450100.0             480000.0
# 1          Cost of Goods Sold             125000.0             125900.0
# 2               Gross Profit              325100.0             354100.0
# 3  Total Operating Expenses               175100.0             180000.0
# 4     Operating Profit (EBIT)             150000.0             174100.0
#
#    2019-03-01 00:00:00  2019-04-01 00:00:00  2019-05-01 00:00:00  \
# 0             430000.0             510000.0             480000.0
# 1             125500.0             125200.0             123500.0
# 2             304500.0             384800.0             356500.0
# 3             178500.0             172200.0             174400.0
# 4             126000.0             212600.0             182100.0
#
#    2019-06-01 00:00:00  2019-07-01 00:00:00  2019-08-01 00:00:00  \
# 0             520000.0             510000.0             410000.0
# ...

# %%
df_transposed = df.set_index("Indicator Name").transpose().reset_index(names=["Date"])
df_transposed.rename_axis(None, axis=1, inplace=True)
df_transposed.tail()
# Out:
#          Date     Income  Cost of Goods Sold  Gross Profit   \
# 19 2020-08-01  388866.87           143013.19      254913.80
# 20 2020-09-01  570927.51            98736.71      424986.04
# 21 2020-10-01  533815.66           139155.84      308642.93
# 22 2020-11-01  587532.93           107095.10      288165.27
# 23 2020-12-01  364365.58           114962.93      290575.23
#
#     Total Operating Expenses    Operating Profit (EBIT)  Taxes      \
# 19                   176715.74                100185.00   87952.72
# 20                   241426.29                191770.18  112911.44
# 21                   155486.15                237650.61   92990.06
# 22                   167105.95                217087.16  100114.13
# 23                   135130.14                165070.59  100067.10
#
#     Net Profit     Net Profit Margin %   Expenses  Cash at EOM  Quick Ratio  \
# 19       12232.28                 0.03  319728.94    539227.55         0.92
# ...

# %%
# Drop Monthly Financial Ratio
df_transposed["Date"] = pd.to_datetime(df_transposed['Date'])

# %%
df_transposed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        24 non-null     datetime64[ns]
#  1   Income                      24 non-null     float64
#  2   Cost of Goods Sold          24 non-null     float64
#  3   Gross Profit                24 non-null     float64
#  4   Total Operating Expenses    24 non-null     float64
#  5   Operating Profit (EBIT)     24 non-null     float64
#  6   Taxes                       24 non-null     float64
#  7   Net Profit                  24 non-null     float64
#  8   Net Profit Margin %         24 non-null     float64
#  9   Expenses                    24 non-null     float64
#  10  Cash at EOM                 24 non-null     float64
#  11  Quick Ratio                 24 non-null     float64
#  12  Current Ratio               24 non-null     float64
# ...

# %%
df_transposed.to_csv("data/finance_data_clean")
