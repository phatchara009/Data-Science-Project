# %% [markdown]
# # Command line in Google Colaboratory Python

# %%
# !ls
# Out:
# friends.csv  sample_data

# %%
# !pwd
# Out:
# /content

# %%
# !cat friends.csv
# Out:
# id,name,age,city
# 1,toy,35,bangkok
# 2,john,32,london
# 3,marry,28,seoul

# %%
# make new folder
# !mkdir data

# %%
# remove folder
# !rmd data
# Out:
# /bin/bash: line 1: rmd: command not found
