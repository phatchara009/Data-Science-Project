# %%
# import os
# os.system("pip install  selenium")
# os.system("pip install  beautifulsoup4")
# os.system("pip install  requests")

# %%
import sys
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # 1. Get name of industries in SET market

# %%
# Step 1: Initialize Chrome driver
# chromedriver_autoinstaller.install()
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")
options.add_argument("--headless=new")
driver = webdriver.Chrome(options)
driver.get('https://www.set.or.th/th/market/index/set/overview')
time.sleep(5)

try:
    click_out = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/div/div[1]/button')
    click_out.click()
except:
    print("can't close this element")

click_out_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[7]/div/div/div[2]/button')
click_out_2.click()

# Find the table using its XPath
table_element = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div/div[2]/div[2]/div/div/div/div/div[2]/div/div/table')

# Get the HTML content of the table
table_html = table_element.get_attribute('outerHTML')

driver.close()

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(table_html, 'html.parser').find_all('tbody')[0]

# Find all table rows including headers
table_rows = soup.find_all('tr', {'aria-labelledby':'accordion-heading'})

# Extract industry name from table
industry_names = [row.find_all("span")[0].text.lower() for row in table_rows]
print(industry_names)
# Out:
# can't close this element
# ['agri',
#  'food',
#  'fashion',
#  'home',
#  'person',
#  'bank',
#  'fin',
#  'insur',
#  'auto',
#  'imm',
#  'paper',
#  'petro',
#  'pkg',
#  'steel',
#  'conmat',
#  'prop',
#  'pf&reit',
#  'cons',
#  'energ',
#  'mine',
#  'comm',
#  'helth',
#  'media',
#  'prof',
#  'tourism',
#  'trans',
#  'etron',
#  'ict']

# %% [markdown]
# # 2. Get name of stocks from each industry

# %%
all_symbol_industry = []
for industry_name in industry_names:
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options)
    driver.get(f'https://www.set.or.th/th/market/index/set/{industry_name}')
    time.sleep(5)
    
    try:
        click_out = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/div/div[1]/button')
        click_out.click()
        # time.sleep(2)
    except:
        print("cannot to close this element")

    click_out_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[7]/div/div/div[2]/button')
    click_out_2.click()
    # time.sleep(2)
    
    try:
        # Find the table using its XPath
        table_element = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div[2]/div[2]/div/div/div/div[3]/div/div[2]/table')

        # Get the HTML content of the table
        table_html = table_element.get_attribute('outerHTML')
        
        driver.close()

        # Parse the HTML content with BeautifulSoup
        soup = BeautifulSoup(table_html, 'html.parser').find_all('tbody')[0]
            
        table_rows = soup.find_all('tr')

        # Extract industry name from table
        symbol_industry = [[industry_name, row.find_all("div", {'class':'symbol pt-1'})[0].text.replace('\n','').strip().lower()] for row in table_rows]
            
        all_symbol_industry += symbol_industry
    except:
        print(f"{industry_name} do not has a table")
    
df = pd.DataFrame(all_symbol_industry, columns=["industry_name", "stock_name"])
df
# Out:
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# mine do not has a table
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
# cannot to close this element
#     industry_name stock_name
# 0            agri         ee
# 1            agri       gfpt
# 2            agri        lee
# 3            agri        ner
# 4            agri       pppm
# ..            ...        ...
# 691           ict      synex
# 692           ict      thcom
# 693           ict        tkc
# 694           ict       true
# 695           ict        twz
#
# [696 rows x 2 columns]

# %%
df.to_csv('symbol_industry.csv', index=False)

# %%
df = pd.read_csv('symbol_industry.csv')

# %% [markdown]
# # 3. Get core business, website, and one report zip link of each stock

# %%
all_symbol_detail = []
for symbol in df["stock_name"].to_list():
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    options.add_argument("--headless=new")
    driver = webdriver.Chrome(options)
    driver.get(f'https://www.set.or.th/th/market/product/stock/quote/{symbol}/company-profile/information')
    # time.sleep(2)
    
    try:
        click_out = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/div/div[1]/button')
        click_out.click()
    except:
        pass

    try:
        click_out_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[7]/div/div/div[2]/button')
        click_out_2.click()
    except:
        pass

    # Find the table using its XPath and Get the HTML content of the table
    # Parse the HTML content with BeautifulSoup
    table_html_1 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/div/div/div/div[1]') \
                        .get_attribute('outerHTML')
    soup_1 = BeautifulSoup(table_html_1, 'html.parser')

    # Find the table using its XPath and Get the HTML content of the table
    # Parse the HTML content with BeautifulSoup
    table_html_2 = driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/div/div/div/div[2]/div[2]/div[1]') \
                        .get_attribute('outerHTML')
    soup_2 = BeautifulSoup(table_html_2, 'html.parser')
    
    driver.close()

    h2 = soup_1.find_all('h2')[0].text.replace('\n', '').strip()
    des = soup_1.find_all('span')[0].text.replace('\n', '').strip()
    link_website = soup_1.find_all('a')[0].text.strip()
    try:
        one_report_link = soup_2.find_all('a')[0]['href']
    except:
        print(f"{symbol} do not have a report")

    stock_detail = [symbol, h2, des, link_website, one_report_link]
    all_symbol_detail.append(stock_detail)
# Out:
# cococo do not have a report
# kcg do not have a report
# blc do not have a report
# nam do not have a report
# credit do not have a report
# fsx do not have a report
# gl do not have a report
# tvh do not have a report
# mgc do not have a report
# psp do not have a report
# window do not have a report
# orn do not have a report
# pace do not have a report
# aimcg do not have a report
# aimirt do not have a report
# ally do not have a report
# amatar do not have a report
# b-work do not have a report
# bareit do not have a report
# bkkcp do not have a report
# boffice do not have a report
# cpncg do not have a report
# cpnreit do not have a report
# cptgf do not have a report
# ctaraf do not have a report
# dreit do not have a report
# erwpf do not have a report
# ftreit do not have a report
# futurepf do not have a report
# gahreit do not have a report
# groreit do not have a report
# gvreit do not have a report
# hpf do not have a report
# hydrogen do not have a report
# impact do not have a report
# inetreit do not have a report
# kpnpf do not have a report
# ktbstmr do not have a report
# lhhotel do not have a report
# lhpf do not have a report
# lhsc do not have a report
# lpf do not have a report
# luxf do not have a report
# m-ii do not have a report
# m-pat do not have a report
# m-stor do not have a report
# mipf do not have a report
# mit do not have a report
# mjlf do not have a report
# mnit do not have a report
# mnit2 do not have a report
# mnrf do not have a report
# popf do not have a report
# ppf do not have a report
# prospect do not have a report
# qhhr do not have a report
# qhop do not have a report
# qhpf do not have a report
# sirip do not have a report
# sprime do not have a report
# sripanwa do not have a report
# sspf do not have a report
# sstrt do not have a report
# tif1 do not have a report
# tlhpf do not have a report
# tnpf do not have a report
# tprime do not have a report
# ttlpf do not have a report
# tu-pf do not have a report
# urbnpf do not have a report
# whabt do not have a report
# whair do not have a report
# whart do not have a report
# nl do not have a report
# brrgif do not have a report
# egatif do not have a report
# kbspif do not have a report
# supereif do not have a report
# advice do not have a report
# tan do not have a report
# phg do not have a report
# safe do not have a report
# ani do not have a report
# btsgif do not have a report
# etl do not have a report
# sav do not have a report
# sino do not have a report
# tffif do not have a report
# 3bbif do not have a report
# dif do not have a report
# gable do not have a report

# %%
df_detail = pd.DataFrame(all_symbol_detail, columns=["symbol", "symbol_name", "description", "link_website", "one_report_link"])
df_detail.tail()
# Out:
#     symbol                                        symbol_name  \
# 691  synex           บริษัท ซินเน็ค (ประเทศไทย) จำกัด (มหาชน)
# 692  thcom                         บริษัท ไทยคม จำกัด (มหาชน)
# 693    tkc  บริษัท เทิร์นคีย์ คอมมูนิเคชั่น เซอร์วิส จำกัด...
# 694   true              บริษัท ทรู คอร์ปอเรชั่น จำกัด (มหาชน)
# 695    twz     บริษัท ทีดับบลิวแซด คอร์ปอเรชั่น จำกัด (มหาชน)
#
#                                            description  \
# 691  จัดจำหน่ายคอมพิวเตอร์ อุปกรณ์ต่อพ่วงคอมพิวเตอร...
# 692  บริษัทประกอบธุรกิจในกลุ่มธุรกิจหลัก 4 กลุ่ม ได...
# 693  ให้บริการออกแบบ วางระบบ จัดหาอุปกรณ์ ติดตั้ง ท...
# 694  ผู้ให้บริการด้านการสื่อสารโทรคมนาคม บริการด้าน...
# 695  ประกอบธุรกิจหลักเป็นผู้จำหน่ายและให้บริการต่าง...
#
#                     link_website  \
# 691      http://www.synnex.co.th
# 692       http://www.thaicom.net
# 693  http://www.tkc-services.com
# 694    http://www.truecorp.co.th
# 695         http://www.twz.co.th
#
#                                        one_report_link
# 691     https://weblink.set.or.th/dat/f56/F0981T22.zip
# 692  https://weblink.set.or.th/dat/f56/0380ONE22022...
# 693     https://weblink.set.or.th/dat/f56/F1674T22.zip
# 694  https://weblink.set.or.th/dat/f56/1756ONE08032...
# 695     https://weblink.set.or.th/dat/f56/F0867T22.zip

# %%
result = df.merge(df_detail, left_on='stock_name', right_on='symbol', how='left').drop(["stock_name"], axis="columns")
result.tail()
# Out:
#     industry_name symbol                                        symbol_name  \
# 691           ict  synex           บริษัท ซินเน็ค (ประเทศไทย) จำกัด (มหาชน)
# 692           ict  thcom                         บริษัท ไทยคม จำกัด (มหาชน)
# 693           ict    tkc  บริษัท เทิร์นคีย์ คอมมูนิเคชั่น เซอร์วิส จำกัด...
# 694           ict   true              บริษัท ทรู คอร์ปอเรชั่น จำกัด (มหาชน)
# 695           ict    twz     บริษัท ทีดับบลิวแซด คอร์ปอเรชั่น จำกัด (มหาชน)
#
#                                            description  \
# 691  จัดจำหน่ายคอมพิวเตอร์ อุปกรณ์ต่อพ่วงคอมพิวเตอร...
# 692  บริษัทประกอบธุรกิจในกลุ่มธุรกิจหลัก 4 กลุ่ม ได...
# 693  ให้บริการออกแบบ วางระบบ จัดหาอุปกรณ์ ติดตั้ง ท...
# 694  ผู้ให้บริการด้านการสื่อสารโทรคมนาคม บริการด้าน...
# 695  ประกอบธุรกิจหลักเป็นผู้จำหน่ายและให้บริการต่าง...
#
#                     link_website  \
# 691      http://www.synnex.co.th
# 692       http://www.thaicom.net
# 693  http://www.tkc-services.com
# 694    http://www.truecorp.co.th
# 695         http://www.twz.co.th
#
#                                        one_report_link
# 691     https://weblink.set.or.th/dat/f56/F0981T22.zip
# 692  https://weblink.set.or.th/dat/f56/0380ONE22022...
# 693     https://weblink.set.or.th/dat/f56/F1674T22.zip
# 694  https://weblink.set.or.th/dat/f56/1756ONE08032...
# 695     https://weblink.set.or.th/dat/f56/F0867T22.zip

# %%
result.to_csv('set_stock_details.csv', index=False, encoding='utf-8-sig')
